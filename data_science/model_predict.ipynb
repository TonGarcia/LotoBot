# %% [markdown]
# # LotoBot Statistics Algorithms
# -------------------------------------
#
# It assumes that the data was already extracted to JSON or CSV (check the README and try the JS in data's folder).
#
# It approach is about to try to get the break even, which means that it is not required to take profit, but expect to at least to do not lose money & earns/take profit as possible.
#
# __Obs.:__ IF no module found, remember activate pyenv.
#
# Strategies used to:
#
# __Generate it Numbers__
# 1. <a href="#Random-Numbers">Random (preventing duplicate bets)</a>
# 1. <a href="#Cloned-Bets">Cloned Bet (Based on previous results)</a>
#
# __Spray the Budget__
# 1. <a href="#Big-Bets">Big Bet</a>
# 1. <a href="#Batch-of-Bets">Batch of Bets</a>
# 1. <a href="#Max-Mixed-Bets">Max Mixed Bets</a>
# 1. <a href="#Most-Rolled-Numbers">Most Rolled Numbers</a>
#
# To prove it, it might show up some statistics:
#
# __Histograms__
# 1. Earnings
# 1. Numbers right
# 1. Break even achieved or not
#
# __Pie Chart__
# 1. Cloned Bets (history, not generated)

# %% [markdown]
# # Load Mined Lotery Data

# %%
import os
import locale
import random
# import pprint
import datetime
import collections
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print('Locale set to:')
locale.setlocale(locale.LC_ALL, 'pt_BR')
# Out:
# Locale set to:
# 'pt_BR'

# %%
def drawns_df_int_rolls():
    global drawns_df
    results = []
    for result in drawns_df.results:
        new_rolls = []
        for roll in result:
            new_rolls.append(int(roll))
        results.append(new_rolls)
    return results

# %%
load_data_start_time = datetime.datetime.now()

data_path = 'data'
draws_data_path = data_path+'/drawns.json'

current_folder = os.path.abspath(os.path.dirname('__file__'))
complete_bets_path = os.path.join(current_folder, draws_data_path)

drawns_df = pd.read_json(complete_bets_path)
# drawns_df['results'].apply(lambda x: rolls_to_int(x))
drawns_df
# Out:
#            date    id                                            results  \
# 0    2003-09-29     1  [18, 20, 25, 23, 10, 11, 24, 14, 06, 02, 13, 0...
# 1    2003-06-10     2  [23, 15, 05, 04, 12, 16, 20, 06, 11, 19, 24, 0...
# 2    2003-10-13     3  [20, 23, 12, 08, 06, 01, 07, 11, 14, 04, 16, 1...
# 3    2003-10-20     4  [16, 05, 25, 24, 23, 08, 12, 02, 17, 18, 01, 1...
# 4    2003-10-27     5  [15, 13, 20, 02, 11, 24, 09, 16, 04, 23, 25, 1...
# 5    2003-03-11     6  [23, 19, 01, 05, 07, 21, 16, 10, 15, 25, 06, 0...
# 6    2003-10-11     7  [22, 04, 15, 08, 16, 14, 21, 23, 12, 01, 25, 1...
# 7    2003-11-17     8  [19, 16, 18, 09, 13, 08, 05, 25, 17, 10, 06, 1...
# 8    2003-11-24     9  [21, 04, 17, 05, 03, 13, 16, 09, 20, 24, 25, 1...
# 9    2003-01-12    10  [24, 19, 08, 23, 06, 02, 20, 11, 09, 03, 04, 1...
# 10   2003-08-12    11  [24, 09, 08, 19, 20, 22, 06, 10, 11, 16, 07, 2...
# 11   2003-12-15    12  [11, 05, 25, 01, 09, 08, 16, 04, 07, 24, 17, 0...
# 12   2003-12-22    13  [13, 06, 10, 05, 08, 14, 03, 11, 16, 15, 09, 1...
# 13   2003-12-29    14  [14, 21, 13, 19, 20, 06, 09, 05, 07, 23, 18, 0...
# 14   2004-05-01    15  [23, 06, 21, 04, 10, 24, 16, 01, 15, 02, 08, 1...
# 15   2004-12-01    16  [24, 17, 05, 08, 07, 12, 13, 02, 15, 10, 19, 2...
# 16   2004-01-19    17  [13, 20, 17, 01, 06, 07, 02, 14, 05, 09, 16, 1...
# 17   2004-01-26    18  [02, 23, 10, 07, 11, 14, 17, 22, 15, 06, 24, 0...
# 18   2004-02-02    19  [15, 17, 10, 23, 11, 24, 13, 14, 06, 02, 08, 0...
# 19   2004-09-02    20  [04, 09, 08, 24, 16, 20, 03, 17, 18, 19, 07, 0...
# 20   2004-02-16    21  [05, 02, 01, 22, 19, 08, 24, 04, 25, 23, 18, 2...
# 21   2004-02-25    22  [13, 15, 05, 09, 07, 10, 01, 03, 22, 02, 25, 1...
# 22   2004-01-03    23  [10, 11, 05, 19, 18, 14, 06, 04, 20, 01, 08, 0...
# 23   2004-08-03    24  [01, 19, 21, 14, 02, 23, 25, 05, 20, 11, 07, 1...
# 24   2004-03-15    25  [04, 23, 20, 02, 05, 13, 07, 09, 24, 03, 01, 0...
# 25   2004-03-22    26  [19, 11, 07, 16, 08, 21, 05, 10, 20, 13, 23, 0...
# 26   2004-03-29    27  [25, 06, 22, 21, 11, 24, 03, 14, 12, 13, 20, 0...
# 27   2004-05-04    28  [18, 21, 11, 07, 09, 03, 20, 16, 14, 12, 13, 1...
# 28   2004-12-04    29  [13, 14, 06, 01, 24, 04, 08, 05, 17, 22, 21, 1...
# 29   2004-04-19    30  [22, 02, 01, 17, 08, 04, 19, 20, 11, 14, 06, 2...
# ...         ...   ...                                                ...
# 1747 2018-10-12  1748  [05, 10, 01, 03, 09, 19, 17, 11, 18, 07, 22, 2...
# 1748 2018-12-12  1749  [19, 04, 09, 24, 12, 25, 06, 21, 15, 13, 20, 2...
# 1749 2018-12-14  1750  [20, 17, 18, 13, 04, 24, 07, 12, 01, 16, 10, 1...
# 1750 2018-12-17  1751  [07, 18, 03, 24, 01, 04, 06, 10, 22, 19, 15, 1...
# 1751 2018-12-19  1752  [15, 07, 04, 13, 16, 06, 22, 09, 20, 18, 03, 0...
# 1752 2018-12-21  1753  [12, 03, 08, 17, 24, 05, 15, 02, 06, 09, 22, 2...
# 1753 2018-12-24  1754  [05, 17, 01, 03, 20, 02, 14, 13, 25, 12, 24, 0...
# 1754 2018-12-26  1755  [09, 03, 25, 21, 02, 22, 18, 08, 20, 23, 11, 0...
# 1755 2018-12-28  1756  [17, 13, 16, 12, 06, 02, 05, 24, 23, 19, 08, 0...
# 1756 2018-12-31  1757  [15, 18, 03, 10, 25, 13, 14, 04, 07, 17, 20, 2...
# 1757 2019-02-01  1758  [23, 22, 09, 04, 17, 20, 12, 19, 02, 10, 14, 0...
# 1758 2019-04-01  1759  [18, 22, 08, 16, 14, 05, 10, 23, 06, 03, 04, 1...
# 1759 2019-07-01  1760  [16, 23, 15, 25, 14, 24, 07, 01, 05, 20, 06, 0...
# 1760 2019-09-01  1761  [11, 21, 02, 19, 13, 25, 03, 17, 09, 05, 10, 0...
# 1761 2019-11-01  1762  [20, 22, 05, 12, 17, 06, 25, 07, 21, 01, 23, 1...
# 1762 2019-01-14  1763  [16, 24, 10, 01, 08, 05, 09, 11, 14, 04, 15, 0...
# 1763 2019-01-16  1764  [15, 06, 02, 25, 19, 14, 23, 17, 04, 20, 16, 0...
# 1764 2019-01-18  1765  [22, 05, 14, 04, 17, 25, 08, 13, 18, 02, 21, 0...
# 1765 2019-01-21  1766  [07, 10, 23, 15, 16, 01, 20, 12, 21, 14, 08, 0...
# 1766 2019-01-23  1767  [09, 15, 02, 20, 05, 19, 24, 16, 06, 04, 07, 2...
# 1767 2019-01-25  1768  [10, 25, 04, 12, 18, 19, 14, 17, 20, 06, 23, 0...
# 1768 2019-01-28  1769  [10, 03, 07, 12, 23, 08, 14, 20, 05, 25, 16, 1...
# 1769 2019-01-30  1770  [21, 02, 11, 18, 20, 05, 07, 19, 23, 14, 12, 0...
# 1770 2019-01-02  1771  [24, 11, 21, 17, 13, 25, 18, 19, 06, 07, 15, 1...
# 1771 2019-04-02  1772  [05, 19, 10, 13, 09, 07, 04, 24, 20, 01, 14, 1...
# 1772 2019-06-02  1773  [08, 16, 19, 18, 13, 02, 10, 25, 09, 05, 17, 2...
# 1773 2019-08-02  1774  [12, 07, 10, 19, 25, 15, 13, 23, 24, 03, 20, 2...
# 1774 2019-11-02  1775  [19, 17, 15, 06, 11, 09, 07, 16, 18, 03, 08, 1...
# 1775 2019-02-13  1776  [11, 25, 19, 17, 12, 24, 07, 23, 18, 06, 13, 0...
# 1776 2019-02-15  1777  [24, 21, 06, 14, 08, 16, 10, 25, 12, 15, 18, 0...
#
#                                              statistics
# 0     {'rolls': '0,00', 'winners_amount': {'11': '25...
# 1     {'rolls': '0,00', 'winners_amount': {'11': '47...
# 2     {'rolls': '0,00', 'winners_amount': {'11': '60...
# 3     {'rolls': '0,00', 'winners_amount': {'11': '70...
# 4     {'rolls': '0,00', 'winners_amount': {'11': '86...
# 5     {'rolls': '0,00', 'winners_amount': {'11': '88...
# 6     {'rolls': '0,00', 'winners_amount': {'11': '96...
# 7     {'rolls': '0,00', 'winners_amount': {'11': '92...
# 8     {'rolls': '0,00', 'winners_amount': {'11': '11...
# 9     {'rolls': '0,00', 'winners_amount': {'11': '11...
# 10    {'rolls': '0,00', 'winners_amount': {'11': '13...
# 11    {'rolls': '0,00', 'winners_amount': {'11': '16...
# 12    {'rolls': '0,00', 'winners_amount': {'11': '15...
# 13    {'rolls': '0,00', 'winners_amount': {'11': '11...
# 14    {'rolls': '0,00', 'winners_amount': {'11': '11...
# 15    {'rolls': '0,00', 'winners_amount': {'11': '14...
# 16    {'rolls': '0,00', 'winners_amount': {'11': '10...
# 17    {'rolls': '0,00', 'winners_amount': {'11': '10...
# 18    {'rolls': '0,00', 'winners_amount': {'11': '13...
# 19    {'rolls': '0,00', 'winners_amount': {'11': '14...
# 20    {'rolls': '0,00', 'winners_amount': {'11': '12...
# 21    {'rolls': '0,00', 'winners_amount': {'11': '86...
# 22    {'rolls': '0,00', 'winners_amount': {'11': '11...
# 23    {'rolls': '0,00', 'winners_amount': {'11': '12...
# 24    {'rolls': '0,00', 'winners_amount': {'11': '12...
# 25    {'rolls': '0,00', 'winners_amount': {'11': '16...
# 26    {'rolls': '0,00', 'winners_amount': {'11': '11...
# 27    {'rolls': '0,00', 'winners_amount': {'11': '13...
# 28    {'rolls': '0,00', 'winners_amount': {'11': '12...
# 29    {'rolls': '0,00', 'winners_amount': {'11': '11...
# ...                                                 ...
# 1747  {'rolls': '24.245.928,00', 'winners_amount': {...
# 1748  {'rolls': '25.496.952,00', 'winners_amount': {...
# 1749  {'rolls': '25.960.788,00', 'winners_amount': {...
# 1750  {'rolls': '24.171.482,00', 'winners_amount': {...
# 1751  {'rolls': '24.693.390,00', 'winners_amount': {...
# 1752  {'rolls': '25.814.150,00', 'winners_amount': {...
# 1753  {'rolls': '17.290.996,00', 'winners_amount': {...
# 1754  {'rolls': '18.950.208,00', 'winners_amount': {...
# 1755  {'rolls': '25.878.256,00', 'winners_amount': {...
# 1756  {'rolls': '18.716.444,00', 'winners_amount': {...
# 1757  {'rolls': '22.547.106,00', 'winners_amount': {...
# 1758  {'rolls': '26.393.780,00', 'winners_amount': {...
# 1759  {'rolls': '36.599.468,00', 'winners_amount': {...
# 1760  {'rolls': '26.714.146,00', 'winners_amount': {...
# 1761  {'rolls': '28.183.534,00', 'winners_amount': {...
# 1762  {'rolls': '25.917.408,00', 'winners_amount': {...
# 1763  {'rolls': '25.808.366,00', 'winners_amount': {...
# 1764  {'rolls': '26.649.634,00', 'winners_amount': {...
# 1765  {'rolls': '25.389.024,00', 'winners_amount': {...
# 1766  {'rolls': '24.657.414,00', 'winners_amount': {...
# 1767  {'rolls': '24.136.628,00', 'winners_amount': {...
# 1768  {'rolls': '24.025.604,00', 'winners_amount': {...
# 1769  {'rolls': '23.664.614,00', 'winners_amount': {...
# 1770  {'rolls': '26.169.126,00', 'winners_amount': {...
# 1771  {'rolls': '24.836.776,00', 'winners_amount': {...
# 1772  {'rolls': '25.763.316,00', 'winners_amount': {...
# 1773  {'rolls': '27.331.900,00', 'winners_amount': {...
# 1774  {'rolls': '25.820.870,00', 'winners_amount': {...
# 1775  {'rolls': '25.996.104,00', 'winners_amount': {...
# 1776  {'rolls': '26.793.496,00', 'winners_amount': {...
#
# [1777 rows x 4 columns]

# %%
load_data_end_time = datetime.datetime.now()
time_diff = int(abs(load_data_end_time - load_data_start_time).total_seconds()*1000)
"Data loaded after " + "{:n}".format(time_diff) + " ms"
# Out:
# 'Data loaded after 542 ms'

# %% [markdown]
# # Settings (config)
# ---------------
#
# Create the bet rules variables
#
# 1. Trials (a list of bets (list of rolls) to prevent duplicate bet)
# 1. Max rolls per bet: 15 (default), 16, ...
# 1. Price for each bet, by amount of rolls (numbers)
# 1. Possible rolls (numbers): 1 to 25
# 1. Max Investment per draw
# 1. Max period investiment (month spend)

# %%
# list of bets by type (populate by algorithms forward)
trials = {
    'random': [], #random rolls bets strategy
    'cloned': [], #cloned bets strategy
    'max_mix': [], #max_mix bets strategy
    'inverted': [] #use the random bets filling it not rolled numbers
} 

bet_types = {
    '15': 2, # R$2,00
    '16': 32, # R$ 32,00
    '17': 272, # R$ 272,00
    '18': 1632 # R$ 1.632,00
}

min_investment = 30 # R$ 30,00 is the minimum investiment for online bet
max_investment = 64 # R$ 64,00 per week (R$ 256 per month)
max_period_investment = max_investment * 4 # max month spend
possible_rolls = range(1,26) # 26 to include 25 in the range
min_bet_rolls = 15 # how much roll per bet (change the price)
max_bet_rolls = 18 # how much roll per bet (change the price)
max_total_investment = max_period_investment + bet_types['17'] + bet_types['18'] # add unique bet for expensive
spend_per_strategy = max_total_investment/len(trials.keys())
str_spend_per_strategy = locale.currency(spend_per_strategy, grouping=True, symbol=None)

print('Max Month Spend: R$'+locale.currency(max_total_investment, grouping=True, symbol=None))
print('Max Spend per Strategy: R$'+str_spend_per_strategy)

# Check possible rolls
# for pr in range(len(possible_rolls)):
#     print(possible_rolls[pr])
# Out:
# Max Month Spend: R$2.160,00
# Max Spend per Strategy: R$540,00

# %% [markdown]
# # Random Numbers

# %% [markdown]
# ### Prevent Duplicated Bet

# %%
def duplicated(bet):
    """This method verify the duplication of received bet in the global trials.

    The global trials are iterate to check if the numbers are present.
    The order is not important, so reorder (sort) numbers to prevent false non-duplicate bet.

    Args:
        bet (list): List of rolls(numbers) in a bet.

    Returns:
        bool: True if it is duplicated, False if not found in early bets.

    Raises:
        AttributeError: no param or None received
        ValueError: not a number received as param or some bet's roll is not a number.

    """
    
    global trials
    duplicated = False
    
    for tt in trials.keys():
        trial_type = trials[tt]
        for trial in trial_type:
            if set(bet) == set(trial):
                duplicated = True
                break
    
    return duplicated

# %% [markdown]
# ### Prevent History Duplicated Bet

# %%
def history_matched(bet):
    """This method verify if there is a match with the received bet in the history drawns.

    The drawns never repeated the same 15 numbers, so it the bet match any, it is burnt.

    Args:
        bet (list): List of rolls(numbers) in a bet.

    Returns:
        bool: True if it is duplicated, False if it was not found in history drawns.

    Raises:
        AttributeError: no param or None received
        ValueError: not a number received as param or some bet's roll is not a number.

    """
    
    global drawns_df
    history_drawns = drawns_df_int_rolls()
    
    for drawn in history_drawns:
        if(set(drawn) == set(bet)): 
            return True
    
    return False

# %% [markdown]
# ### Generate Random Numbers

# %%
def gen_random_rolls_bet(max_bet_rolls=15):
    """This method generate an unique random rolls bet.

    Every bet generated is tested if unique in the trials list.

    Args:
        max_bet_rolls (int): Amount of rolls for the bet, the default is 15 (minimum).

    Returns:
        list: List of rolls as a single bet checked if duplicate or not.

    Raises:
        AttributeError: no param or None received
        ValueError: not a number received as param or some bet's roll is not a number.

    """
    
    global trials
    bet = []

    # Generate BETs while it is not unique in TRIALS LIST
    while True:
        # Generate ROLLs while the BET is not FILLED to it MAX
        while len(bet) < max_bet_rolls:
            # Generate ROLLs while ROLL not unique in the BET
            while True:
                roll = random.randint(1,25)
                if roll not in bet:
                    bet.append(roll)
                    break
            # Generated unique ROLL to the BET
        # Generated a COMPLETE BET, now check if it is duplicated
        if not duplicated(bet) and not history_matched(bet):
            break
    
    trials['random'].append(bet)
    return bet

# %% [markdown]
# # Cloned Bets

# %% [markdown]
# # Max Mixed Bets

# %% [markdown]
# # Most Rolled Numbers

# %% [markdown]
# # Big Bets

# %% [markdown]
# # Batch of Bets

# %% [markdown]
# # Data Statistics
#
# What the data says, a look in the history before start the trials generator

# %% [markdown]
# ### History Results Exploration - PieChart

# %%
results_series = pd.Series(np.concatenate(drawns_df.results))
rolls_counted = results_series.value_counts().sort_index().rename_axis('x').reset_index(name='f')
rolls_counted.plot()

# %%
rolls_counted.plot.bar(x='x', y='f', rot=0)

# %%
last_drawns = drawns_df[-100:].copy()
last_drawns = last_drawns.reset_index()
last_results_series = pd.Series(np.concatenate(last_drawns.results))
last_rolls_counted = last_results_series.value_counts().sort_index().rename_axis('x').reset_index(name='f')
last_rolls_counted.plot.bar(x='x', y='f', rot=0)

# %%
last_rolls_counted.sort_values(by=['f'], ascending=False)[:16]
# Out:
#      x   f
# 9   10  67
# 0   01  62
# 18  19  62
# 12  13  62
# 17  18  59
# 23  24  58
# 2   03  58
# 4   05  57
# 15  16  57
# 20  21  57
# 24  25  57
# 6   07  57
# 11  12  56
# 5   06  56
# 16  17  56
# 21  22  55

# %% [markdown]
# ## Most Rolled Numbers

# %%
rolls_counted.sort_values(by=['f'], ascending=False)
# Out:
#      x     f
# 12  13  1033
# 23  24  1024
# 10  11  1022
# 0   01  1019
# 13  14  1014
# 9   10  1010
# 2   03  1007
# 1   02  1007
# 3   04  1005
# 24  25  1004
# 14  15  1001
# 16  17  1000
# 19  20  1000
# 4   05   993
# 21  22   992
# 11  12   990
# 17  18   990
# 18  19   983
# 8   09   981
# 22  23   981
# 6   07   977
# 5   06   974
# 20  21   971
# 15  16   954
# 7   08   946

# %% [markdown]
# # Random for Min. Invest.

# %%
random_bets = []
min_bets_ammount = min_investment/bet_types['15']

mbai = 0
while mbai < min_bets_ammount:
    bet = gen_random_rolls_bet()
    random_bets.append(bet)
    print(bet)
    mbai = mbai+1
# Out:
# [24, 19, 10, 25, 5, 16, 9, 23, 12, 13, 15, 8, 4, 18, 2]
# [14, 17, 5, 24, 12, 18, 9, 25, 22, 10, 2, 19, 20, 7, 16]
# [8, 15, 14, 9, 4, 19, 18, 22, 16, 25, 20, 12, 17, 3, 5]
# [16, 14, 7, 23, 5, 24, 10, 13, 9, 18, 2, 20, 21, 17, 25]
# [13, 17, 16, 19, 25, 24, 10, 4, 3, 6, 18, 7, 23, 15, 9]
# [22, 5, 6, 20, 8, 13, 11, 24, 9, 17, 16, 1, 18, 19, 23]
# [24, 21, 14, 2, 3, 6, 18, 19, 1, 9, 10, 5, 8, 12, 15]
# [4, 6, 3, 5, 7, 15, 18, 22, 14, 24, 21, 11, 25, 20, 1]
# [15, 16, 3, 10, 4, 8, 19, 23, 21, 2, 24, 11, 22, 9, 6]
# [13, 15, 21, 23, 22, 2, 4, 16, 18, 3, 19, 5, 17, 8, 7]
# [9, 5, 6, 3, 24, 19, 15, 13, 10, 25, 21, 2, 14, 23, 8]
# [24, 8, 5, 10, 22, 3, 23, 15, 17, 11, 7, 18, 12, 1, 13]
# [6, 15, 22, 25, 8, 17, 11, 3, 18, 2, 10, 23, 19, 12, 20]
# [19, 6, 4, 21, 25, 9, 17, 10, 14, 3, 8, 24, 15, 5, 18]
# [2, 18, 4, 10, 13, 5, 1, 25, 15, 11, 21, 9, 24, 3, 8]

# %%
# check if drawns df are ints not strings
# drawns_df_int_rolls()[0][0]

# %% [markdown]
# # Bets Historical Profitability

# %%
random_bets_set = []

# Iterate generated random bets
for random_bet in random_bets:
    random_bet_set = set(random_bet)
    # Iterate the list of history result
    for result in drawns_df.results:
        # Iterate the rolls of each result to count how much matched
        for roll in result:
            
    
    drawns_df.results
# Out:
#   File "<ipython-input-16-fc9f49d52f3e>", line 12
#     drawns_df.results
#     ^
# IndentationError: expected an indented block

# %%
drawns_df
